# %%
import sys
import os

# Add the src directory to the Python path
sys.path.append(os.path.abspath(os.path.join("..", "src")))

# %%
import pandas as pd
from preprocessing import preprocess_articles

# %%
path = "../data/News_Category_Dataset_v3.json"
df = preprocess_articles(path)

# %%
df.head()
# Out:
#     category                                               text  \
# 0  U.S. NEWS  million americans roll sleeve omicrontargete c...
# 1  U.S. NEWS  american airlines flyer charge ban life punch ...
# 2     COMEDY  funniest tweet cat dog week sept dog not under...
# 3  PARENTING  funniest tweet parent week sept accidentally g...
# 4  U.S. NEWS  woman call cop black birdwatcher lose lawsuit ...
#
#                                             headline  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...
# 1  American Airlines Flyer Charged, Banned For Li...
# 2  23 Of The Funniest Tweets About Cats And Dogs ...
# 3  The Funniest Tweets From Parents This Week (Se...
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...
#
#                                    short_description
# 0  Health experts said it is too early to predict...
# 1  He was subdued by passengers and crew when he ...
# 2  "Until you have a dog you don't understand wha...
# 3  "Accidentally put grown-up toothpaste on my to...
# 4  Amy Cooper accused investment firm Franklin Te...

# %%
df['category'].value_counts().plot(kind='bar', figsize=(12,5), title='News Category Distribution')
# Out:
# <Axes: title={'center': 'News Category Distribution'}, xlabel='category'>

# %%
df.to_csv("../data/cleaned_data.csv", index=False)
